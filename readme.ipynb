# %%
import pandas as pd
from dataexplore.src.correlation_analysis_module import CorrelationAnalysis 

data = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [2, 4, 6, 8, 10],
    'C': [5, 4, 3, 2, 1]
})

correlation_analysis = CorrelationAnalysis(data)

# Calculate correlation coefficients
correlation_coefficients = correlation_analysis.calculate_correlation()
print("Correlation Coefficients:")
print(correlation_coefficients)

# Generate correlation matrix
correlation_matrix = correlation_analysis.generate_correlation_matrix()
print("\nCorrelation Matrix:")
print(correlation_matrix)

# Visualize correlation matrix (heatmap)
correlation_analysis.visualize_correlation_matrix()

# Calculate Pearson correlation coefficient
pearson_corr = correlation_analysis.calculate_pearson_correlation('A', 'B')
print("\nPearson Correlation Coefficient between A and B:", pearson_corr)

# Calculate Spearman correlation coefficient
spearman_corr = correlation_analysis.calculate_spearman_correlation('A', 'B')
print("Spearman Correlation Coefficient between A and B:", spearman_corr)

# Test correlation significance
correlation_significance = correlation_analysis.test_correlation_significance('A', 'B')
print("\nCorrelation Significance Testing (Pearson, Spearman):", correlation_significance)
# Out:
# Correlation Coefficients:
#      A    B    C
# A  1.0  1.0 -1.0
# B  1.0  1.0 -1.0
# C -1.0 -1.0  1.0
#
# Correlation Matrix:
#      A    B    C
# A  1.0  1.0 -1.0
# B  1.0  1.0 -1.0
# C -1.0 -1.0  1.0
# Pearson Correlation Coefficient between A and B: 1.0
# Spearman Correlation Coefficient between A and B: 0.9999999999999999
#
# Correlation Significance Testing (Pearson, Spearman): (1.0, 0.9999999999999999)

# %%
from dataexplore.src.data_encouder_module import DataEncoder

db = DataEncoder()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ihorvoznyi/Desktop/University/СМП/РГР/dataexplore/readme.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/Users/ihorvoznyi/Desktop/University/%D0%A1%D0%9C%D0%9F/%D0%A0%D0%93%D0%A0/dataexplore/readme.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from dataexplore.src.data_encouder_module import DataEncoder
# ----> <a href='vscode-notebook-cell:/Users/ihorvoznyi/Desktop/University/%D0%A1%D0%9C%D0%9F/%D0%A0%D0%93%D0%A0/dataexplore/readme.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> db = DataEncoder()
#
# TypeError: DataEncoder.__init__() missing 1 required positional argument: 'data'
